# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Mon Dec 23 10:23:45 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !pip install langchain
# !pip install langchain-core
# !pip install langchain-community
# !pip install langchain-groq
# !pip install sentence-transformers
# !pip install faiss-cpu
# !pip install unstructured
# !pip install "unstructured[local-inference]"
# !pip install chromadb
# !pip install Cython
# !pip install tiktoken
# Out:
# ...
# ...
# ...
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# ...
#   Using cached bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.8 kB)
# ...
#   Using cached kubernetes-31.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached mmh3-5.0.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# ...
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# ...
#   Using cached starlette-0.41.3-py3-none-any.whl.metadata (6.0 kB)
# ...
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# ...
#   Using cached opentelemetry_exporter_otlp_proto_common-1.29.0-py3-none-any.whl.metadata (1.8 kB)
# ...
#   Using cached opentelemetry_proto-1.29.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached protobuf-5.29.2-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# ...
#   Using cached opentelemetry_instrumentation_asgi-0.50b0-py3-none-any.whl.metadata (1.9 kB)
# ...

# %%
# It will ask you to enter Groq-API_key, Please paste and then hit enter

import getpass
import os

if "GROQ_API_KEY" not in os.environ:
    os.environ["GROQ_API_KEY"] = getpass.getpass("Provide your GROQ API TOKEN: ")
# Out:
# Provide your GROQ API TOKEN: ··········

# %%
# Before runnning this code please upload 'essay_India_Cricket.txt' in current virtual environment in colab

from langchain.document_loaders import TextLoader
loader = TextLoader('/content/Essay_India_Cricket.txt')
documents = loader.load()

# %%
documents
# Out:
# [Document(metadata={'source': '/content/Essay_India_Cricket.txt'}, page_content="essay about india\n\nIndia, a land of myriad cultures, traditions, and landscapes, stands as a beacon of diversity and resilience in the global tapestry. With a rich history spanning thousands of years, India's story is one of ancient civilizations, dynasties, and profound philosophical insights that continue to shape its identity today.\n\nGeographically, India boasts a breathtaking diversity from the towering Himalayas in the north to the sun-kissed beaches of the south, and from the arid deserts of Rajasthan to the lush forests of Kerala. This diversity extends to its people, who speak hundreds of languages and practice multiple religions, creating a mosaic of cultures that is both vibrant and complex.\n\nIndia's history is marked by the rise and fall of empires such as the Mauryas, Guptas, and Mughals, each leaving a lasting imprint on the country's architecture, art, and societal norms. The country'
# ...

# %%
import textwrap

def wrap_text_preserve_newlines(text, width=110):
    # Split the input text into lines based on newline characters
    lines = text.split('\n')

    # Wrap each line individually
    wrapped_lines = [textwrap.fill(line, width=width) for line in lines]

    # Join the wrapped lines back together using newline characters
    wrapped_text = '\n'.join(wrapped_lines)

    return wrapped_text

# %%
print(wrap_text_preserve_newlines(str(documents[0])))
# Out:
# page_content='essay about india
#
# India, a land of myriad cultures, traditions, and landscapes, stands as a beacon of diversity and resilience
# in the global tapestry. With a rich history spanning thousands of years, India's story is one of ancient
# civilizations, dynasties, and profound philosophical insights that continue to shape its identity today.
#
# Geographically, India boasts a breathtaking diversity from the towering Himalayas in the north to the sun-
# kissed beaches of the south, and from the arid deserts of Rajasthan to the lush forests of Kerala. This
# diversity extends to its people, who speak hundreds of languages and practice multiple religions, creating a
# mosaic of cultures that is both vibrant and complex.
#
# India's history is marked by the rise and fall of empires such as the Mauryas, Guptas, and Mughals, each
# leaving a lasting imprint on the country's architecture, art, and societal norms. The country's spiritual
# ...

# %%
# Text Splitter
from langchain.text_splitter import CharacterTextSplitter
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

# %%
len(docs)
# Out:
# 9

# %%
docs[1]
# Out:
# Document(metadata={'source': '/content/Essay_India_Cricket.txt'}, page_content="India's history is marked by the rise and fall of empires such as the Mauryas, Guptas, and Mughals, each leaving a lasting imprint on the country's architecture, art, and societal norms. The country's spiritual legacy is exemplified by ancient texts like the Vedas and Upanishads, which continue to influence not only Hinduism but also other philosophies worldwide.\n\nIn the realm of arts and culture, India has given birth to classical dance forms like Bharatanatyam, Odissi, Kathak, and Kuchipudi, each telling stories of devotion, love, and mythology. Its music, ranging from classical ragas to Bollywood melodies, resonates with emotions that transcend language barriers.")

# %%
docs[2]
# Out:
# Document(metadata={'source': '/content/Essay_India_Cricket.txt'}, page_content="Economically, India is one of the world's fastest-growing major economies, embracing technological advancements while grappling with challenges of poverty and development disparities. The country's IT industry, centered in cities like Bangalore and Hyderabad, is a global powerhouse, driving innovation and creating opportunities.\n\nSocially, India faces complexities stemming from its caste system and diversity of languages and religions. Efforts toward gender equality and social justice continue to evolve, supported by progressive legislation and grassroots movements advocating for change.\n\nPolitically, India is the world's largest democracy, with a robust electoral system and a history of peaceful transitions of power. Its foreign policy balances regional influence with global aspirations, seeking to maintain stability while addressing regional challenges.")

# %%
# !pip install sentence-transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 41.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.20.3
#     Uninstalling tokenizers-0.20.3:
#       Successfully uninstalled tokenizers-0.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# chromadb 0.5.23 requires tokenizers<=0.20.3,>=0.13.2, but you have tokenizers 0.21.0 which is incompatible.
# ...

# %%
from langchain.embeddings import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings()
# Out:
# <ipython-input-13-a8d3548f7db6>:3: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embeddings = HuggingFaceEmbeddings()
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# ...

# %%
from langchain.vectorstores import FAISS

db = FAISS.from_documents(docs, embeddings)

# %%
query = "explain about indian premier league"
docs = db.similarity_search(query)

# %%
print(wrap_text_preserve_newlines(str(docs[0].page_content)))
# Out:
# The Indian Premier League (IPL), launched in 2008, revolutionized the cricketing landscape by blending
# entertainment with top-notch cricketing action. The league's success has not only attracted global stars but
# also provided a platform for young Indian players to showcase their talent and earn recognition on a grand
# stage.
#
# Cricket in India is not just about the players and matches; it's also about the fans who pack stadiums, paint
# their faces in team colors, and live and breathe every moment of the game. The fervor surrounding cricket
# transcends generations, with families gathering around television sets or radios to cheer for their favorite
# players and teams.

# %%
import langchain_groq
from langchain_groq import ChatGroq

GROQ_LLM = ChatGroq(
            api_key=os.getenv("GROQ_API_KEY"),
            model="gemma2-9b-it"
        )

# %%
from langchain.chains.question_answering import load_qa_chain

chain = load_qa_chain(GROQ_LLM, chain_type="stuff")
# Out:
# <ipython-input-18-95de09154617>:3: LangChainDeprecationWarning: This class is deprecated. See the following migration guides for replacements based on `chain_type`:
# stuff: https://python.langchain.com/docs/versions/migrating_chains/stuff_docs_chain
# map_reduce: https://python.langchain.com/docs/versions/migrating_chains/map_reduce_chain
# refine: https://python.langchain.com/docs/versions/migrating_chains/refine_chain
# map_rerank: https://python.langchain.com/docs/versions/migrating_chains/map_rerank_docs_chain
#
# See also guides on retrieval and question-answering here: https://python.langchain.com/docs/how_to/#qa-with-rag
#   chain = load_qa_chain(GROQ_LLM, chain_type="stuff")

# %%
query = "HOW IS INDIAN ECONOMY"
docs = db.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# "According to the text provided, economically India is one of the world's fastest-growing major economies. \n"

# %%
query = "explain about indian geograpy?"
docs = db.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# 'The provided text explains that India has a geographically diverse landscape, ranging from the Himalayas in the north to beaches in the south, deserts in Rajasthan, and forests in Kerala. \n'

# %%
query = "tell me about indian democracy?"
docs = db.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# "India is the world's largest democracy.  It has a robust electoral system and a history of peaceful transitions of power. \n"

# %%
query = "tell mr about indian classical dance?"
docs = db.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# 'India has several classical dance forms, including Bharatanatyam, Odissi, Kathak, and Kuchipudi. Each of these dance forms tells stories of devotion, love, and mythology. \n'

# %%
query = "explain about indian caste system?"
docs = db.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# 'The essay explains that socially, India faces complexities stemming from its caste system and diversity of languages and religions.  \n'

# %%
query = "explain about indian ancient empires?"
docs = db.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# "This essay provides information about India's geography, history, culture, economy, society, politics, and more. \n\nHowever, it doesn't go into detail about specific Indian ancient empires like the Mauryas, Guptas, and Mughals beyond mentioning their names and impact. \n\n\nTo learn more about those empires, you would need to consult additional resources. \n"

# %%
query = "explain about indians obsession with cricket?"
docs = db.similarity_search(query)
chain.run(input_documents=docs, question=query)
# Out:
# "The provided text explains that cricket in India is more than just a sport; it's a national obsession. \n\nHere's why, according to the text:\n\n* **Unifying force:** Cricket transcends differences in language, religion, and region, bringing Indians together.\n* **Passion and pride:**  It reflects the country's passion for competition and serves as a symbol of national pride and unity.\n* **Cultural fabric:** Cricket has been deeply ingrained in Indian culture since its introduction during the British colonial era.\n* **Fervent fans:** Indians passionately follow the game, packing stadiums, celebrating victories, and living and breathing every moment.\n* **Generational appeal:** The love for cricket spans generations, with families sharing the experience together.\n\n\nThe text argues that cricket is a cultural phenomenon in India, binding the nation together and reflecting its values of passion, perseverance, and excellence. \n"
